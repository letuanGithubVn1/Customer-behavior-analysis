# %% [markdown]
# ## **📊 Customer Behaviour Analysis**

# %% [markdown]
# ### **1️⃣ Introduction**

# %% [markdown]
# **Objective**: Understand relationships between customer demographics and purchasing behavior.
#
# **Application**:
# - **Marketing**: Tailor marketing strategies based on customer age, gender, or income.
# - **Customer Segmentation**: Segment customers into groups based on correlated behaviors and demographics.

# %% [markdown]
# ### **2️⃣ Calculations**

# %% [markdown]
# Import Pandas, Matplotlib and Seaborn:

# %%
# YOUR CODE
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Then load the data by the following link:\
# https://raw.githubusercontent.com/letuanGithubVn1/Customer-behavior-analysis/refs/heads/main/customer_data.csv

# %%
# YOUR CODE
df = pd.read_csv('https://raw.githubusercontent.com/letuanGithubVn1/Customer-behavior-analysis/refs/heads/main/customer_data.csv')

# %% [markdown]
# Let's take a look at the given data first. Output the first 5 rows:

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Income  SpendingScore  SatisfactionRating
# 0           1   28  Female   48754     100.000000                 5.0
# 1           2   38    Male   47750      59.833417                 5.0
# 2           3   37  Female   59467      65.855645                 5.0
# 3           4   36    Male   46047     100.000000                 5.0
# 4           5   35  Female   78391      86.398144                 5.0

# %% [markdown]
# As we know, a correlation can be calculated only based on numeric columns. So, let's make a list of numeric columns:

# %%
print(df.select_dtypes(include=[np.number]))
# Out:
#       CustomerID  Age  Income  SpendingScore  SatisfactionRating
# 0              1   28   48754     100.000000                 5.0
# 1              2   38   47750      59.833417                 5.0
# 2              3   37   59467      65.855645                 5.0
# 3              4   36   46047     100.000000                 5.0
# 4              5   35   78391      86.398144                 5.0
# ...          ...  ...     ...            ...                 ...
# 1045        1046   51   88111      85.270469                 5.0
# 1046        1047   44   71111      84.386193                 5.0
# 1047        1048   50   50776     100.000000                 5.0
# 1048        1049   40   46568      99.862150                 5.0
# 1049        1050   48   64043      61.329137                 3.0
#
# [1050 rows x 5 columns]

# %%
# YOUR CODE
numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
numeric_cols
# Out:
# ['CustomerID', 'Age', 'Income', 'SpendingScore', 'SatisfactionRating']

# %% [markdown]
# Then calculate a correlation matrix using the method `.corr()`
#
# > **💡 Don't forget...**
# >
# > You need to use only numeric columns!

# %%
# YOUR CODE
customer_corr = df[numeric_cols].corr()
customer_corr
# Out:
#                     CustomerID       Age    Income  SpendingScore  \
# CustomerID            1.000000  0.018894  0.032899       0.019374
# Age                   0.018894  1.000000  0.656541      -0.157697
# Income                0.032899  0.656541  1.000000      -0.084817
# SpendingScore         0.019374 -0.157697 -0.084817       1.000000
# SatisfactionRating   -0.030074 -0.057356 -0.018254       0.551581
#
#                     SatisfactionRating
# CustomerID                   -0.030074
# Age                          -0.057356
# Income                       -0.018254
# SpendingScore                 0.551581
# SatisfactionRating            1.000000

# %% [markdown]
# Finally, let's visualise the correlation matrix using Seaborn heatmap.
#
# Set the title **"Customer Behavior Correlation Matrix"** to the chart.

# %%
# YOUR CODE
plt.figure(figsize=(10, 8))
sns.heatmap(customer_corr, annot=True, cmap='coolwarm')
plt.title('Customer Behavior Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Customer Behavior Correlation Matrix')

# %% [markdown]
# ### **3️⃣ Insights & Conclusions**

# %% [markdown]
# ```
# 🔶 **Significant Correlations:**
#
# ***Age and Income***
# Correlation coefficient: 0.66
# → This strong positive correlation suggests that older individuals tend to earn higher incomes — a trend aligned with increased earnings over time due to experience and career progression.
#
# ***Spending Score and Satisfaction***
# Rating Correlation coefficient: 0.55
# → A moderate positive correlation indicates that customers with higher spending levels often report greater satisfaction, reflecting a potential link between spending behavior and customer sentiment.
#
# 🔷 **Weak or Insignificant Correlations:**
#
# ***Age and SpendingScore***
# Correlation coefficient: -0.16
# → A mild negative correlation suggests that older customers may spend slightly less, possibly due to lower consumption needs or more conservative spending habits.
#
# ***Income and SpendingScore***
# Correlation coefficient: -0.085
# → Indicates a very weak negative correlation, implying that income is not a strong predictor of spending behavior.
#
# Income and Satisfaction Rating
# Correlation coefficient: -0.018
# → Essentially no relationship is observed between income and satisfaction level.
#
# 📌 **Summary**:
#
# The most notable patterns are found in the ***Age–Income and Spending Score–SatisfactionRating pairs**, suggesting that these variables may be useful for predicting customer behavior.
#
# However, **most other variables lack strong correlation**, indicating that further customer insight should be derived from more advanced or complementary analytical methods.
# ```

# %% [markdown]
# Write any insights and conclusions you found.
#
# > **📌 Note that!**
# >
# >
# > It is considered <u>good practice to examine correlations for all columns one by one</u>.\
# This is crucial because, in analysis, even the absence of correlation is significant. The lack of a relationship between two variables is also a useful observation from which conclusions can and sometimes should be drawn.

# %% [markdown]
# ### **4️⃣ Recommendations for Marketing**

# %% [markdown]
# Write any recomandations for markting strategy based on your insights & conclusions.
